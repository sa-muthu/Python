# %% [markdown]
# # CSV file handling in Python

# %%
Linux Path ----> /home/user/Desktop/IMS24XXX/

# %% [markdown]
# Import the iris dataset, reading from csv file.

# %%
import csv
with open('/home/iisertvm/Desktop/IMS24XXX/data.csv','r') as file:
  read = csv.reader(file)
  for row in read:
    print(row)
# Out:
# ['Name', 'Class']
# ['Ram', 'xi']
# ['Ajith', 'xii']

# %%
#csv.DictReader()
with open('/home/iisertvm/Desktop/IMS24XXX/data.csv','r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        print(dict(row))
# Out:
# {'Name': 'Ram', 'Class': 'xi'}
# {'Name': 'Ajith', 'Class': 'xii'}

# %%
#Writing the contents to a csv file

import csv
with open('/home/iisertvm/Desktop/IMS24XXX/newdata.csv','w') as file:
  write = csv.writer(file)
  write.writerow(['Name','Class'])
  write.writerow(['Ram','xi'])
  write.writerow(['Ajith','xii'])
    
with open('/home/iisertvm/Desktop/IMS24XXX/newdata.csv','r') as file:
  reader = csv.DictReader(file)
  for row in reader:
    print(row)

#https://www.edureka.co/blog/python-matplotlib-tutorial/
#https://www.geeksforgeeks.org/plotting-graph-for-iris-dataset-using-seaborn-and-matplotlib/
# Out:
# {'Name': 'Ram', 'Class': 'xi'}
# {'Name': 'Ajith', 'Class': 'xii'}

# %%
with open('/home/iisertvm/Desktop/IMS24XXX/data.csv','w') as file:
  write = csv.writer(file)
  field = ['Name','Class']
  rows = [['Ram','xi'],['Ajith','xii']]
  write.writerow(field)
  write.writerows(rows)
    
with open('/home/iisertvm/Desktop/IMS24XXX/data.csv','r') as file:
  reader = csv.DictReader(file)
  for row in reader:
    print(dict(row))
# Out:
# {'Name': 'Ram', 'Class': 'xi'}
# {'Name': 'Ajith', 'Class': 'xii'}

# %%
import csv

# Append new data to the CSV file
with open('/home/iisertvm/Desktop/IMS24XXX/data.csv','a') as file:
    write = csv.writer(file)
    rows = [
        ['Anu','x'],
        ['Rahul','xi'],
        ['Meera','xii']
    ]
    write.writerows(rows)
# Read the file using DictReader
with open('/home/iisertvm/Desktop/IMS24XXX/data.csv','r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        print(dict(row))
# Out:
# {'Name': 'Ram', 'Class': 'xi'}
# {'Name': 'Ajith', 'Class': 'xii'}
# {'Name': 'Anu', 'Class': 'x'}
# {'Name': 'Rahul', 'Class': 'xi'}
# {'Name': 'Meera', 'Class': 'xii'}

# %%
filename = "/home/iisertvm/Desktop/IMS24XXX/imdb_top_4.csv"
header = ("Rank", "Rating", "Title")
data = [
(1, 9.2, "The Shawshank Redemption(1994)"),
(2, 9.2, "The Godfather(1972)"),
(3, 9, "The Godfather: Part II(1974)"),
(4, 8.9, "Pulp Fiction(1994)")
]

# %%
def writer(header, data, filename):
  with open (filename, "w", newline = "") as csvfile:
    movies = csv.writer(csvfile)
    movies.writerow(header)
    movies.writerows(data)
      
writer(header, data, filename)
#newline="" is used to prevent extra blank lines from appearing in the CSV file when writing rows.

# %%
import csv

filename = "/home/iisertvm/Desktop/IMS24XXX/data.csv/imdb_top_4.csv"

header = ("Rank", "Rating", "Title")

data = [
    (1, 9.2, "The Shawshank Redemption (1994)"),
    (2, 9.2, "The Godfather (1972)"),
    (3, 9, "The Godfather: Part II (1974)"),
    (4, 8.9, "Pulp Fiction (1994)")
]

def writer(header, data, filename):
    with open(filename, "w", newline="") as csvfile:
        movies = csv.writer(csvfile)
        movies.writerow(header)
        movies.writerows(data)

writer(header, data, filename)
